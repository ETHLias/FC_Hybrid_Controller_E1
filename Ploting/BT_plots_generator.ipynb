# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=12)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=12)    # fontsize of the tick labels
plt.rc('ytick', labelsize=12)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=12)  # fontsize of the figure title

# %%
# define variable

Battery_Cap = 1 #[kwh]
Start_Percent_BAT = 0.9 # from 0 - 1, 1 = 100% charged


# -------------------------------------
Q_max = Battery_Cap*1000*3600   # Maximum Charge of the Battery [As]

Q_0 = Q_max*Start_Percent_BAT # At start, how much juice is in the BAT.

t_start = 0 #[s] Time start
t_step = 60 #[s] Time step
t_end = 60*60 #[s] Time end

span = int(t_end/t_step)

SoC = np.array([0, 0.2, 0.8, 0.93, 1])
u_oc = np.array([54, 630, 666, 720, 756])


# Plot out the continuous signal with noise introduced.
plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(SoC, u_oc, label='Open Circle Voltage')
plt.xticks(np.linspace(0,1,11))
plt.yticks(np.linspace(0,800,9))
plt.xlabel('SoC')
plt.ylabel('$u_{oc}$ [V]')
plt.legend()

plt.savefig("u_oc_SoC.pdf")
plt.show()

# %%
SoC = np.array([0, 0.2, 0.4, 0.8, 1])
R_i = np.array([9, 3.6, 2.7, 2.7, 1.8])


# Plot out the continuous signal with noise introduced.
plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(SoC, R_i, label='Internal Resistance')
plt.xticks(np.linspace(0,1,11))
#plt.xlim()
plt.ylim(1, 9.5)
plt.yticks(np.linspace(1,9,9))
plt.xlabel('SoC')
plt.ylabel('$R_{i}$ $[\Omega]$')
plt.legend()

plt.savefig("R_i_SoC.pdf")
plt.show()

# %%
P_FC = np.linspace(0,100000,10001)


a = 7.95454545454545e-14
b = 1.48851010101010e-08
c = 6.67424242424242e-05

dm_H2 = a*(P_FC*P_FC) + b*P_FC + c

# Plot out the continuous signal with noise introduced.
plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(P_FC/1000, dm_H2*1000, label='Hydrogen Mass Flow Rate')
plt.xticks(np.linspace(0,100,11))
#plt.xlim()
#plt.ylim(1, 9.5)
plt.yticks(np.linspace(0,2.5,11))
plt.xlabel("$P_{FC}$ [kW]")
plt.ylabel('$\dot{m}_{H2}$ [g/s]')
plt.legend()

plt.savefig("dm_H2_P_FC.pdf")
plt.show()

# %%
P_FC = np.linspace(0,100000,10001)

a = 6.55497412831353e-07
b = 0.110383876465320
c = 7821.39907716565

P_Comp = a*(P_FC*P_FC) + b*P_FC + c

# Plot out the continuous signal with noise introduced.
plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(P_FC/1000, P_Comp/1000, label='Compressor Power')
plt.xticks(np.linspace(0,100,11))
#plt.xlim()
#plt.ylim(1, 9.5)
#plt.yticks(np.linspace(0,2.5,11))
plt.xlabel("$P_{FC}$ [kW]")
plt.ylabel('$P_{Comp}$ [kW]')
plt.legend()

plt.savefig("P_Comp_P_FC.pdf")
plt.show()

# %%
Q_1 = np.array([-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1])
Q_2_lambda_04_20000 = np.array([0.000407456,0.000402413,0.000398723,0.000396431,0.000395591,0.000396263,0.000408053,0.000436479,0.000485303,0.000619395,0.000818688])
Q_2_lambda_04_40000 = np.array([0.000832431,0.000821024,0.00081097,0.000802315,0.000795112,0.000789419,0.000782119,0.000791454,0.000821187,0.00087792,0.000975493])
Q_2_lambda_04_60000 = np.array([0.00132104,0.00130327,0.00128685,0.00127184,0.00125827,0.00124621,0.00121982,0.00121007,0.00122071,0.00125835,0.00133683])
Q_2_lambda_04_80000 = np.array([0.00187329,0.00184916,0.00182637,0.00180499,0.00178506,0.00176664,0.00172116,0.00169231,0.00168386,0.00170242,0.00176181])
Q_2_lambda_04_100000 = np.array([0.00248917,0.00245868,0.00242953,0.00240178,0.00237549,0.00235071,0.00228613,0.0022382,0.00221066,0.00221012,0.00225042])
Q_2_lambda_04_120000 = np.array([0.00316869,0.00313183,0.00309632,0.00306221,0.00302956,0.00299841,0.00291474,0.00284772,0.00280109,0.00278146,0.00280267])



Q_min_1 = np.array([-0.2, 0.2, 0.4, 0.6, 0.8])
Q_min_2 = np.array([0.000395591, 0.000782119, 0.00121007, 0.00168386, 0.00221012])


plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
#plt.plot(Q_1, Q_2_lambda_04_120000, label='$\lambda = 0.4$ 120kW', linestyle ='')
plt.plot(Q_1, Q_2_lambda_04_100000, label='$\lambda = 0.4$, $P_{req}=100$kW', linestyle ='--')
plt.plot(Q_1, Q_2_lambda_04_80000, color = 'tab:blue', label='$\lambda = 0.4$, $P_{req}=80$kW', linestyle ='-', linewidth=2.0)
plt.plot(Q_1, Q_2_lambda_04_60000, label='$\lambda = 0.4$, $P_{req}=60$kW', linestyle =':', linewidth=2.0)
plt.plot(Q_1, Q_2_lambda_04_40000, label='$\lambda = 0.4$, $P_{req}=40$kW', linestyle ='-.')
plt.plot(Q_1, Q_2_lambda_04_20000, label='$\lambda = 0.4$, $P_{req}=20$kW')

plt.scatter(Q_min_1, Q_min_2, label='Minumum', marker='o')
#plt.plot(Q_1, Q_2_lambda_0_3_SoC_low, label='$\lambda = 0.3$ Low SoC')
plt.xticks(np.linspace(-1,1,11))
#plt.xlim(0, 0.003)
plt.ylim(0.0002, 0.0026)
plt.yticks(np.linspace(0.00025,0.0025,10))
plt.xlabel("$Q$")
plt.ylabel('$H$')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.tight_layout()

plt.savefig("H_Q_P.pdf")
plt.show()

# %%
Q_1 = np.array([-1,-0.8,-0.6,-0.4,-0.2,0,0.2,0.4,0.6,0.8,1])

Q_2_lambda_03_80000 = np.array([0.00191765,0.00188502,0.00185358,0.00182333,0.00179434,0.00176664,0.00169183,0.00163092,0.00158675,0.00156425,0.00157382])
Q_2_lambda_04_80000 = np.array([0.00187329,0.00184916,0.00182637,0.00180499,0.00178506,0.00176664,0.00172116,0.00169231,0.00168386,0.00170242,0.00176181])
Q_2_lambda_05_80000 = np.array([0.00182893,0.00181329,0.00179917,0.00178665,0.00177578,0.00176664,0.00175049,0.0017537,0.00178098,0.00184058,0.00194979])
Q_2_lambda_06_80000 = np.array([0.00178457,0.00177742,0.00177197,0.00176831,0.0017665,0.00176664,0.00177982,0.0018151,0.0018781,0.00197874,0.00213778])
Q_2_lambda_07_80000 = np.array([0.00174022,0.00174155,0.00174477,0.00174996,0.00175722,0.00176664,0.00180916,0.00187649,0.00197522,0.0021169,0.00232577])



Q_2_lambda_09_80000 = np.array([0.00312673,0.00313072,0.00313696,0.00314555,0.00315661,0.00317028,0.0032285,0.003317,0.00344423,0.00362505,0.0038906])



Q_min_1 = np.array([0.8, 0.6, 0.2, -0.2, -1])
Q_min_2 = np.array([0.00156425, 0.00168386, 0.00175049, 0.0017665, 0.00174022])


plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()

plt.plot(Q_1, Q_2_lambda_03_80000, label='$\lambda = 0.3$, $P_{req}=80$kW', linestyle = ':', linewidth=2.0)
plt.plot(Q_1, Q_2_lambda_04_80000, color = 'tab:blue', label='$\lambda = 0.4$, $P_{req}=80$kW', linestyle = 'solid', linewidth=2.5)
plt.plot(Q_1, Q_2_lambda_05_80000, label='$\lambda = 0.5$, $P_{req}=80$kW', linestyle = 'dashdot')
plt.plot(Q_1, Q_2_lambda_06_80000, label='$\lambda = 0.6$, $P_{req}=80$kW', linestyle = '--')
plt.plot(Q_1, Q_2_lambda_07_80000, label='$\lambda = 0.7$, $P_{req}=80$kW', linestyle = '-')


#plt.plot(Q_1, Q_2_lambda_09_90000, label='$\lambda = 0.9$ 90kW', linestyle = ' ')




plt.scatter(Q_min_1, Q_min_2, label='Minumum', marker='o')


#plt.plot(Q_1, Q_2_lambda_0_3_SoC_low, label='$\lambda = 0.3$ Low SoC')
plt.xticks(np.linspace(-1,1,11))
#plt.xlim()
#plt.ylim(1, 9.5)
#plt.yticks(np.linspace(0,2.5,11))
plt.xlabel("$Q$")
plt.ylabel('$H$')
plt.legend()

plt.savefig("H_Q.pdf")
plt.show()

# %%
# computational time: computation time xxx s / simulation time 3000s
# For each simulated second need xxx s to calculate

# Hydrogen consumption

#Resolution = np.array([6, 11, 21, 41, 101, 201, 501])
Resolution = np.array([11, 21, 41, 101, 201, 501])

#Computation_Time = np.array([18.60, 18.78, 19.26, 20.06, 22.13, 25.89, 35,98]) #in second
Computation_Time = np.array([18.78, 19.26, 20.06, 22.13, 25.89, 35,98]) #in second

#H2_consumption = np.array([3304.370165, 3309.015345, 3309.287, 3309.01896, 3308.9888, 3309.044399, 3309.0503127]) # in g
H2_consumption = np.array([3309.015345, 3309.287, 3309.01896, 3308.9888, 3309.044399, 3309.0503127]) # in g

plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.scatter(Resolution, H2_consumption, label='Resolution = 6 Step', marker='o', linewidth=3.0)

plt.yticks(np.linspace(3308,3310,9))
#plt.xlim()
#plt.ylim(1, 9.5)
#plt.xticks(np.linspace(0,500,21))


plt.ylabel("Simulated Total $H_2$ Consumption [g]")
plt.xlabel('Resolution [Step]')

#plt.legend()

plt.savefig("Resolution_H2_used.pdf")
plt.show()

# %%
# computational time: computation time xxx s / simulation time 3000s
# For each simulated second need xxx s to calculate

# Hydrogen consumption

#Resolution = np.array([6, 11, 21, 41, 101, 201, 501])
Resolution = np.array([11, 21, 41, 101, 201, 501])

#Computation_Time = np.array([18.60, 18.78, 19.26, 20.06, 22.13, 25.89, 35,98]) #in second
Computation_Time = np.array([18.78, 19.26, 20.06, 22.13, 25.89, 35.98]) #in second

#H2_consumption = np.array([3304.370165, 3309.015345, 3309.287, 3309.01896, 3308.9888, 3309.044399, 3309.0503127]) # in g
H2_consumption = np.array([3309.015345, 3309.287, 3309.01896, 3308.9888, 3309.044399, 3309.0503127]) # in g

plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(Resolution, Computation_Time, label='Computation Time', marker='o')

plt.yticks(np.linspace(18,36,11))
#plt.xlim()
#plt.ylim(1, 9.5)
#plt.xticks(np.linspace(0,500,21))
plt.xlabel("Resolution")

plt.ylabel("Computation Time [s]")
plt.xlabel('Resolution [Step]')

plt.legend()

plt.savefig("Resolution_Computation_Time.pdf")
plt.show()

# %%
# FC-Delay

t_FC_a = np.array([0,7,10, 14, 20])
P_FC_a = np.array([10, 80, 80, 40, 40])





t_P_FC_req_a = np.array([0,10,10.0000001])
P_FC_req_a = np.array([80, 80,40])
t_P_FC_req_b = np.array([10,20])
P_FC_req_b = np.array([40, 40])




plt.figure(figsize=(10, 6))
#plt.axhline(y=1, color='g', linestyle='--')
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(t_FC_a, P_FC_a, label='FC Power', linestyle='-', linewidth=3.0, color = 'tab:blue')


plt.plot(t_P_FC_req_a, P_FC_req_a, label='FC Power Request', linestyle='--', linewidth=2.5, color = 'tab:orange')
plt.plot(t_P_FC_req_b, P_FC_req_b, linestyle='--', linewidth=2.5, color = 'tab:orange')

#plt.yticks(np.linspace(0,100,11))
#plt.xlim()
#plt.ylim(1, 9.5

#plt.yticks(np.linspace(18,36,11))
#plt.xlim()
#plt.ylim(1, 9.5)
plt.xticks(np.linspace(0,20,21))
plt.xlabel("Resolution")

plt.ylabel("$P_{FC}$ [kW]")
plt.xlabel('Time [s]')

plt.legend()

plt.savefig("P_FC_delay.pdf")
plt.show()

# %%
# Define the file path
file_path = 'Time.txt'

# Initialize a list to collect the data
data = []

# Open the file and read it line by line
with open(file_path, 'r') as file:
    for line in file:
        # Replace commas with periods
        line = line.replace(',', '.')
        # Split the line into values and convert them to float
        values = [float(value) for value in line.split()]
        # Extend the data list with the values
        data.extend(values)

# Convert the data list to a NumPy array
Time = np.array(data)
#---------------------------------------------------------------------------------
# Define the file path
file_path = 'Q.txt'

# Initialize a list to collect the data
data = []

# Open the file and read it line by line
with open(file_path, 'r') as file:
    for line in file:
        # Replace commas with periods
        line = line.replace(',', '.')
        # Split the line into values and convert them to float
        values = [float(value) for value in line.split()]
        # Extend the data list with the values
        data.extend(values)

# Convert the data list to a NumPy array
Q = np.array(data)
#-------------------------------------------------------------------------------
# Define the file path
file_path = 'SoC.txt'

# Initialize a list to collect the data
data = []

# Open the file and read it line by line
with open(file_path, 'r') as file:
    for line in file:
        # Replace commas with periods
        line = line.replace(',', '.')
        # Split the line into values and convert them to float
        values = [float(value) for value in line.split()]
        # Extend the data list with the values
        data.extend(values)

# Convert the data list to a NumPy array
SoC = np.array(data)
#-------------------------------------------------------------------------------
# Define the file path
file_path = 'P_Pilot_req.txt'

# Initialize a list to collect the data
data = []

# Open the file and read it line by line
with open(file_path, 'r') as file:
    for line in file:
        # Replace commas with periods
        line = line.replace(',', '.')
        # Split the line into values and convert them to float
        values = [float(value) for value in line.split()]
        # Extend the data list with the values
        data.extend(values)

# Convert the data list to a NumPy array
P_Pilot_req = np.array(data)
#-------------------------------------------------------------------------------
# Define the file path
file_path = 'P_BAT.txt'

# Initialize a list to collect the data
data = []

# Open the file and read it line by line
with open(file_path, 'r') as file:
    for line in file:
        # Replace commas with periods
        line = line.replace(',', '.')
        # Split the line into values and convert them to float
        values = [float(value) for value in line.split()]
        # Extend the data list with the values
        data.extend(values)

# Convert the data list to a NumPy array
P_BAT = np.array(data)
#-------------------------------------------------------------------------------
# Define the file path
file_path = 'P_FC.txt'

# Initialize a list to collect the data
data = []

# Open the file and read it line by line
with open(file_path, 'r') as file:
    for line in file:
        # Replace commas with periods
        line = line.replace(',', '.')
        # Split the line into values and convert them to float
        values = [float(value) for value in line.split()]
        # Extend the data list with the values
        data.extend(values)

# Convert the data list to a NumPy array
P_FC = np.array(data)
#-------------------------------------------------------------------------------
# Define the file path
file_path = 'Lambda.txt'

# Initialize a list to collect the data
data = []

# Open the file and read it line by line
with open(file_path, 'r') as file:
    for line in file:
        # Replace commas with periods
        line = line.replace(',', '.')
        # Split the line into values and convert them to float
        values = [float(value) for value in line.split()]
        # Extend the data list with the values
        data.extend(values)

# Convert the data list to a NumPy array
Lambda = np.array(data)

# %%
#plt.figure(figsize=(10, 6))
plt.figure(figsize=(10, 4.5))
plt.grid()
plt.plot(Time, P_Pilot_req/1000, label='$P_{Pilot,req}$')
#plt.xticks(np.linspace(0,1,11))
#plt.xlim()
#plt.ylim(1, 9.5)
plt.yticks(np.linspace(0,90,10))
plt.xlabel('Time [s]')
plt.ylabel('$P_{Pilot,req}$ [kW]')
plt.legend()

plt.savefig("P_Pilot_req_plot.pdf")
plt.show()

# %%
plt.figure(figsize=(10, 4.5))
#plt.axhline(y=1, color='g', linestyle='--')
plt.axhline(y=0, color='grey', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(Time, Q, label='Q')
#plt.xticks(np.linspace(0,1,11))
#plt.xlim()
#plt.ylim(1, 9.5)
#plt.yticks(np.linspace(1,9,9))
plt.xlabel('Time [s]')
plt.ylabel('$Q$')
plt.legend()

plt.savefig("Q_plot.pdf")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.axhline(y=0.65, color='g', linestyle='--', label = "$SoC_{des}$")
#plt.axhline(y=0, color='g', linestyle='--')
#plt.title("")
#plt.stem(T_DIS_Morse, DIS_Morse_Signal_w_N_Raw, 'y' ,label='Sampled Discrete Signal')
plt.grid()
plt.plot(Time, SoC, label='$SoC$')
plt.plot(Time, Lambda, label='$\lambda$')
#plt.xticks(np.linspace(0,1,11))
#plt.xlim()
#plt.ylim(0.4, 1)
plt.yticks(np.linspace(0.1,1,10))
plt.xlabel('Time [s]')
plt.ylabel('$SoC$, $\lambda$')
plt.legend()

plt.savefig("SoC_Lambda_plot.pdf")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.grid()
plt.axhline(y=0, color='black', linestyle='--')
plt.plot(Time, P_BAT/1000, label='$P_{BAT}$', color="tab:orange")
plt.plot(Time, P_FC/1000, label='$P_{FC}$', color="tab:blue")
plt.plot(Time, P_Pilot_req/1000, label='$P_{Pilot,req}$', color="purple", linestyle='-')
#plt.xticks(np.linspace(0,1,11))
#plt.xlim()
plt.ylim(-15, 95)
plt.yticks(np.linspace(-10,90,11))
plt.xlabel('Time [s]')
plt.ylabel('$P$ [kW]')
plt.legend()

plt.savefig("P_Multi_plot.pdf")
plt.show()
